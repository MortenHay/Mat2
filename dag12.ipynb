# %%
from sympy import *
init_printing()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = Matrix([[1,-1],[3,-2]])
b = Matrix([1,1])
d = Matrix([1,2])
A.charpoly()
# Out:
# PurePoly(lambda**2 + lambda + 1, lambda, domain='ZZ')

# %%
a1,a2 = 1,1

# %% [markdown]
# Stabilt

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = Symbol('s')
H = (-d.transpose()*(A-s*eye(2)).inv()*b)[0].simplify()
H
# Out:
#  3⋅s + 5
# ──────────
#  2
# s  + s + 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n = Symbol('n', integer=True)
b = 1/n**3
c = -I*b/2
c
# Out:
# -ⅈ
# ────
#    3
# 2⋅n

# %%
t = Symbol('t',real=True)
u = Sum(c*exp(I*n*t),(n,-oo,oo))
u
# Out:
#   ∞
# _____
# ╲
#  ╲
#   ╲        ⅈ⋅n⋅t
#    ╲   -ⅈ⋅ℯ
#    ╱   ──────────
#   ╱          3
#  ╱        2⋅n
# ╱
# ‾‾‾‾‾
# n = -∞

# %%
y = Sum(c*H.subs(s,I*n)*exp(I*n*t),(n,-oo,oo))
y
# Out:
#   ∞
# _____
# ╲
#  ╲
#   ╲                    ⅈ⋅n⋅t
#    ╲   -ⅈ⋅(3⋅ⅈ⋅n + 5)⋅ℯ
#    ╱   ──────────────────────
#   ╱       3 ⎛   2          ⎞
#  ╱     2⋅n ⋅⎝- n  + ⅈ⋅n + 1⎠
# ╱
# ‾‾‾‾‾
# n = -∞

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = Symbol('N',integer=True,positive=True)
SN = Sum(c*H.subs(s,I*n)*exp(I*n*t),(n,-N,N))
SN
# Out:
#   N
# _____
# ╲
#  ╲
#   ╲                    ⅈ⋅n⋅t
#    ╲   -ⅈ⋅(3⋅ⅈ⋅n + 5)⋅ℯ
#    ╱   ──────────────────────
#   ╱       3 ⎛   2          ⎞
#  ╱     2⋅n ⋅⎝- n  + ⅈ⋅n + 1⎠
# ╱
# ‾‾‾‾‾
# n = -N

# %%
fejl = Sum(c*H.subs(s,I*n)*exp(I*n*t),(n,N+1,oo)) + Sum(c*H.subs(s,I*n)*exp(I*n*t),(n,-N-1,-oo))
# Out:
#     -∞                                  ∞
#   _____                               _____
#   ╲                                   ╲
#    ╲                                   ╲
#     ╲                      ⅈ⋅n⋅t        ╲                     ⅈ⋅n⋅t
#      ╲     -ⅈ⋅(3⋅ⅈ⋅n + 5)⋅ℯ              ╲    -ⅈ⋅(3⋅ⅈ⋅n + 5)⋅ℯ
#      ╱     ────────────────────── +      ╱    ──────────────────────
#     ╱         3 ⎛   2          ⎞        ╱        3 ⎛   2          ⎞
#    ╱       2⋅n ⋅⎝- n  + ⅈ⋅n + 1⎠       ╱      2⋅n ⋅⎝- n  + ⅈ⋅n + 1⎠
#   ╱                                   ╱
#   ‾‾‾‾‾                               ‾‾‾‾‾
# n = -N - 1                          n = N + 1

# %%
fejl2 = Sum(abs(I*exp(I*n*t)/(2*n**3)),(n,N+1,oo)) + Sum(abs(I*exp(I*n*t)/(2*n**3)),(n,-N-1,-oo))
fejl2
# Out:
#     -∞                ∞
#   _____             _____
#   ╲                 ╲
#    ╲       │1 │      ╲      │1 │
#     ╲      │──│       ╲     │──│
#      ╲     │ 3│        ╲    │ 3│
#      ╱     │n │ +      ╱    │n │
#     ╱      ────       ╱     ────
#    ╱        2        ╱       2
#   ╱                 ╱
#   ‾‾‾‾‾             ‾‾‾‾‾
# n = -N - 1        n = N + 1

# %%
fejl3 = S(1)/2*Sum(1/n**3,(n,N+1,oo)) - S(1)/2*Sum(1/n**3,(n,-N-1,-oo))
fejl3
# Out:
#       -∞              ∞
#      ____            ____
#      ╲               ╲
#       ╲      1        ╲     1
#        ╲     ──        ╲    ──
#        ╱      3        ╱     3
#       ╱      n        ╱     n
#      ╱               ╱
#      ‾‾‾‾            ‾‾‾‾
#   n = -N - 1      n = N + 1
# - ───────────── + ────────────
#         2              2

# %%
fejl4 = S(1)/2*Sum(1/n**3,(n,N+1,oo)) + S(1)/2*Sum(1/n**3,(n,N+1,oo))
fejl4
# Out:
#     ∞
#    ____
#    ╲
#     ╲     1
#      ╲    ──
#      ╱     3
#     ╱     n
#    ╱
#    ‾‾‾‾
# n = N + 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f = 1/t**3
t0 = Symbol('t0',real = True, positive = True)
ep = S(1)/100
eq1 = Eq(ep,integrate(f,(t,t0+1,oo)))
ceiling(solve(eq1)[0])
# Out:
# 7

# %%
integrate(f,(t,t0+1,oo))
# Out:
#   t₀   1
#   ── + ─
#   2    2
# ─────────
#         3
# (t₀ + 1)

# %%
ep
# Out:
# 1/100

# %%
fejl4.subs(N,7).evalf()
# Out:
# 0.00884978459788389
