# %%
from sympy import *
init_printing()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = Symbol('a')
solve((-(a+2))**2+a)
# Out:
# [-4, -1]
